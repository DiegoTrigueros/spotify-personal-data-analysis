# %%
# TODO
# Heatmap of music listening frequency
# Barplot of artist vs listened minutes
# Valence index tendency
# Create predictive model of whether I would like a song or not

# %%
import sys
print(sys.executable)
# Out:
# D:\anaconda3\python.exe

# %%
import pandas as pd
import numpy as np
import json
import spotipy
import spotipy.util as util
import requests
import matplotlib.pyplot as plt
import plotly.express as px
from spotipy.oauth2 import SpotifyClientCredentials
from jsonmerge import merge
from collections import OrderedDict

# %%
def prepare_files(f1_path, f2_path):
    # Removing data from 2019 as analysis is for 2020 only
    with open(f1_path, 'r', encoding='utf-8') as source_file:
        data = json.load(source_file)
        new_data = [element for element in data if "2019" not in element['endTime']]
    
    new_file_path = "/Google Drive/Personal Projects/Spotify Data Analysis/MyData/UpdatedData.json"
    
    # Writing clean data into new file to preserve original
    with open(new_file_path, 'w', encoding='utf-8') as dest_file:
        data = json.dump(new_data, dest_file, indent=4)
        
    file_one = open(new_file_path, encoding='utf-8')
    file_one = json.load(file_one, encoding='utf-8')
    file_two = open(f2_path, encoding='utf-8')
    file_two = json.load(file_two, encoding='utf-8')
    
    print(file_one)
    
    # Merge both files into a single variable
    merged_data = merge(file_one, file_two)
    return merged_data

# %%
# Retrieving data
streaming_history_p1 = "/Google Drive/Personal Projects/Spotify Data Analysis/MyData/StreamingHistory0.json"
streaming_history_p2 = "/Google Drive/Personal Projects/Spotify Data Analysis/MyData/StreamingHistory1.json"
data = prepare_files(streaming_history_p1, streaming_history_p2)

# %%
def extract_values(column_name):
    return [i[column_name] for i in data]

# Create dataframe from data
songs_data = pd.DataFrame()
songs_data['artist_name'] = extract_values('artistName')
songs_data['track_name'] = extract_values('trackName')
songs_data['end_time'] = extract_values('endTime')
songs_data['ms_played'] = extract_values('msPlayed')

# %%
songs_data.head()
# Out:
#   artist_name        track_name          end_time  ms_played
# 0   Bad Bunny  Si Veo a Tu Mamá  2020-06-18 21:53     170971
# 1   Bad Bunny                <3  2020-06-18 21:56     157967
# 2   Bad Bunny   Hablamos Mañana  2020-06-18 22:00     240253
# 3   Bad Bunny                <3  2020-06-18 22:13       4759
# 4   Bad Bunny  Si Veo a Tu Mamá  2020-06-18 23:55       1040

# %%
# Access the spotify API
username = 'dgtj18'
client_id = '3424ef36fc3b45199b19d77e9db4b44c'
client_secret = '76b735824b8949a0a1cd75b4011ad465'
redirect_uri = 'http://localhost:7777/callback'
scope = 'user-read-recently-played'

token = util.prompt_for_user_token(username=username, scope=scope, client_id=client_id, client_secret=client_secret,
                                   redirect_uri=redirect_uri)

client_credentials_manager = SpotifyClientCredentials(client_id="3424ef36fc3b45199b19d77e9db4b44c",
                                                     client_secret="76b735824b8949a0a1cd75b4011ad465")
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# Get spotify ID for every track
def retrieve_id(track_name: str, artist: str, token: str):
    headers = {
        'Accept': 'application/json',
        'Content-Type': 'application/json',
        'Authorization': f'Bearer ' + token,
    }
    track_artist = track_name+ " " +artist
    params = [
        ('q', track_artist),
        ('type', 'track')
    ]
    try:
        response = requests.get('https://api.spotify.com/v1/search', headers = headers,
                               params = params, timeout = 10)
        json = response.json()
        first_result = json['tracks']['items'][0]
        track_id = first_result['id']
        return track_id
    except:
        return None

# %%
# Splitting the dataframe in three to avoid credentials timeout
data_split = np.array_split(songs_data, 5)

# %%
# for df in data_split:
#     token = util.prompt_for_user_token(username=username, scope=scope, client_id=client_id, client_secret=client_secret,
#                                redirect_uri=redirect_uri)
#     songs_data['track_id'] = songs_data.apply(lambda x: retrieve_id(x['track_name'], 
#                                                         x['artist_name'], 
#                                                         token), axis=1)

# %%
# %store songs_data
# %store -r songs_data
songs_data.tail()
# Out:
#      artist_name                   track_name          end_time  ms_played  \
# 6370        Acru                        Crudo  2020-12-16 23:14      92115
# 6371      Trueno                     Atrevido  2020-12-16 23:37       1707
# 6372      Trueno                     Atrevido  2020-12-16 23:40     194747
# 6373      Eminem  Godzilla (feat. Juice WRLD)  2020-12-16 23:44     210800
# 6374        Duki                  Hello Cotto  2020-12-16 23:47     217250
#
#                     track_id
# 6370  3Y0njfS1jG0EzUDKtjvS5a
# 6371  6tMqYyCVU2aKgUahMvJz2S
# 6372  6tMqYyCVU2aKgUahMvJz2S
# 6373  7FIWs0pqAYbP91WWM0vlTQ
# 6374  422Avi2VjqZKCVzstKmqog

# %%
# Delete tracks without ID
null_free_data = songs_data["track_id"].dropna()
null_free_data.sample(60)
# Out:
# 4687    29wJiSQcze8HEmxkUQykyp
# 4149    2MbdDtCv5LUVjYy9RuGTgC
# 5070    7HrnRmbiDEJUoRD9PNnKwO
# 3347    6gBFPUFcJLzWGx4lenP6h2
# 6001    3O3cmxeQ4M2nbbFilGDT6i
# 1043    2pUfYjXbYoLBqzbVOcDmPn
# 1664    1dKjLvlAPTPlhRCFyA84Z9
# 5860    0lc70Jh2s1iOMuv9XIEhFy
# 4064    7x4ClpwHSyNJgCsMUFRVU7
# 2876    5PmK5pRspJq5ki30zgyv7G
# 1094    2ONADYjJvqYVwjWavuY0H1
# 4955    0nGLRyRhkkGm1vEFkUMctq
# 4937    7lj2BqZyPehFyu3y6N1qqw
# 4934    3qKGvSu1inEZKwYQnMavNA
# 3602    5jaczAoWttFi8Cyz5AIgim
# 2070    1MZqHpFyB4j5tFCFNvURou
# 1283    2UAWYufVaO3EnUUNzl0ppO
# 5847    48XgkAh1fkcZqA2EZWCDX6
# 4165    5jaczAoWttFi8Cyz5AIgim
# 5967    6zFMeegAMYQo0mt8rXtrli
# 4995    3WUrXHDowLk25UtALiohVD
# 3723    7gfyrnHMieXMjIW4n2p5wf
# 8       4AmkflbQtBjOjNwSt92P1u
# 6203    4CyNQIQasNUfpT9nrnmX0S
# 2161    0hwEhPxCBLKiqeBMZavGAv
# 4858    2byu6eeLWaBq88ZtusqU4V
# 6188    48XgkAh1fkcZqA2EZWCDX6
# 4681    2BBKvpGV9f0Dub9ixzns2g
# 4018    1prdmkn7pO2S0FJChx0fN4
# 3399    4ea9w8c4ROqiZpJVhfBA3m
# 274     20fBuVybkHgjF6vNhSMROD
# 3159    0Y3bl8IzUsGvccFu74OLPB
# 5129    79XZYbexRnaHO7cf5nJZZw
# 2803    6rz0dTA0PdhXImFV5EjM0w
# 2264    0TUW9faHNaBmi89wsYGp9y
# 4114    1WRZ8DhNQmacE37Mcoj21f
# 3156    4AmkflbQtBjOjNwSt92P1u
# 5885    6tMqYyCVU2aKgUahMvJz2S
# 2448    2u3EyuCqqV31woqGvO9LBz
# 2503    6Cgj3VVfcYJN9vZbMVcKRd
# 323     3VCo2tJEa1a8GDCvSIqwP0
# 3100    6tMqYyCVU2aKgUahMvJz2S
# 1645    03e3pnRddWmYOVQlzs3Qnb
# 4907    01UQtSmwS81vFhFIYssL3X
# 5042    6zeTz2j5A9G6gEKi34ks05
# 5554    7ikRId3U9AXd6tfF2fbItC
# 5389    5jaczAoWttFi8Cyz5AIgim
# 3539    6gBFPUFcJLzWGx4lenP6h2
# 3479    2WcPl9wtGox6EUla9BAW7W
# 2966    0TUW9faHNaBmi89wsYGp9y
# 5820    6kT6RwLeEV4XxM526NJYXT
# 945     5fqjfiMOFapIb8uFcxBStH
# 1010    7FFDZHJdRQjgLb2UspiiWN
# 3883    6VCuvpA6yVnV6jUt498IGO
# 2079    41wtwzCZkXwpnakmwJ239F
# 2557    1OWAG0ddOR2ffSa6RjaJ8k
# 3512    70yIbQ6nKHuKyqubhydwAn
# 4906    7ikRId3U9AXd6tfF2fbItC
# 2333    3Y0njfS1jG0EzUDKtjvS5a
# 2887    1gthlIZ4aYGOz4NFsaaZQA
# Name: track_id, dtype: object

# %%
tracks = list(OrderedDict.fromkeys(null_free_data))

# %%
my_features = pd.DataFrame(columns=["song_id","energy", "liveness","tempo","speechiness",
                                "acousticness","instrumentalness","danceability",
                                "duration_ms","loudness","valence",
                                "mode","key"])

# Add features for each song
# for song in tracks:
#     features = sp.audio_features(tracks = [song])[0]
#     if features is not None:
#         my_features = my_features.append({"song_id":song,
#                                     "energy":features['energy'], 
#                                     "liveness":features['liveness'],
#                                     "tempo":features['tempo'],
#                                     "speechiness":features['speechiness'],
#                                     "acousticness":features['acousticness'],
#                                     "instrumentalness":features['instrumentalness'],
#                                     "danceability":features['danceability'],
#                                     "duration_ms":features['duration_ms'],
#                                     "loudness":features['loudness'],
#                                     "valence":features['valence'],
#                                     "mode":features['mode'],
#                                     "key":features["key"],
#                                  },ignore_index=True)
#     else:
#         pass

# %%
# %store my_features
# %store -r my_features
my_features.head()
# Out:
#                   song_id  energy  liveness    tempo  speechiness  \
# 0  41wtwzCZkXwpnakmwJ239F   0.603    0.1340  129.928       0.0646
# 1  4MZSqgwlE71CWZ6qQ3gkKm   0.665    0.1520   80.353       0.2290
# 2  1V8XneTrX6kKeoxYbk4x6h   0.677    0.0998  156.019       0.0469
# 3  4f49sFQko7jHLEFd3tCf5p   0.839    0.0946  170.011       0.2400
# 4  4AmkflbQtBjOjNwSt92P1u   0.729    0.5870   91.992       0.1290
#
#    acousticness  instrumentalness  danceability duration_ms  loudness  \
# 0        0.4020          0.000005         0.900      170972    -5.313
# 1        0.6020          0.000002         0.631      157967    -7.589
# 2        0.0869          0.000000         0.683      240253    -4.496
# 3        0.0206          0.000077         0.801      229027    -3.267
# 4        0.0811          0.000000         0.825      151307    -5.478
#
#    valence mode key
# 0    0.824    1   2
# 1    0.634    0  10
# 2    0.514    1   1
# 3    0.792    0   1
# 4    0.661    1   8

# %%
# Merge Ids with the rest of the song info
my_streaming_data = pd.merge(songs_data, my_features, how="left", left_on="track_id", right_on="song_id")
my_streaming_data
# Out:
#      artist_name                   track_name          end_time  ms_played  \
# 0      Bad Bunny             Si Veo a Tu Mamá  2020-06-18 21:53     170971
# 1      Bad Bunny                           <3  2020-06-18 21:56     157967
# 2      Bad Bunny              Hablamos Mañana  2020-06-18 22:00     240253
# 3      Bad Bunny                           <3  2020-06-18 22:13       4759
# 4      Bad Bunny             Si Veo a Tu Mamá  2020-06-18 23:55       1040
# ...          ...                          ...               ...        ...
# 6370        Acru                        Crudo  2020-12-16 23:14      92115
# 6371      Trueno                     Atrevido  2020-12-16 23:37       1707
# 6372      Trueno                     Atrevido  2020-12-16 23:40     194747
# 6373      Eminem  Godzilla (feat. Juice WRLD)  2020-12-16 23:44     210800
# 6374        Duki                  Hello Cotto  2020-12-16 23:47     217250
#
#                     track_id                 song_id  energy  liveness  \
# 0     41wtwzCZkXwpnakmwJ239F  41wtwzCZkXwpnakmwJ239F   0.603    0.1340
# 1     4MZSqgwlE71CWZ6qQ3gkKm  4MZSqgwlE71CWZ6qQ3gkKm   0.665    0.1520
# 2     1V8XneTrX6kKeoxYbk4x6h  1V8XneTrX6kKeoxYbk4x6h   0.677    0.0998
# 3     4MZSqgwlE71CWZ6qQ3gkKm  4MZSqgwlE71CWZ6qQ3gkKm   0.665    0.1520
# 4     41wtwzCZkXwpnakmwJ239F  41wtwzCZkXwpnakmwJ239F   0.603    0.1340
# ...                      ...                     ...     ...       ...
# 6370  3Y0njfS1jG0EzUDKtjvS5a  3Y0njfS1jG0EzUDKtjvS5a   0.827    0.2230
# 6371  6tMqYyCVU2aKgUahMvJz2S  6tMqYyCVU2aKgUahMvJz2S   0.640    0.3740
# 6372  6tMqYyCVU2aKgUahMvJz2S  6tMqYyCVU2aKgUahMvJz2S   0.640    0.3740
# 6373  7FIWs0pqAYbP91WWM0vlTQ  7FIWs0pqAYbP91WWM0vlTQ   0.745    0.2920
# 6374  422Avi2VjqZKCVzstKmqog  422Avi2VjqZKCVzstKmqog   0.785    0.0506
#
#         tempo  speechiness  acousticness  instrumentalness  danceability  \
# 0     129.928       0.0646        0.4020          0.000005         0.900
# 1      80.353       0.2290        0.6020          0.000002         0.631
# 2     156.019       0.0469        0.0869          0.000000         0.683
# 3      80.353       0.2290        0.6020          0.000002         0.631
# 4     129.928       0.0646        0.4020          0.000005         0.900
# ...       ...          ...           ...               ...           ...
# 6370   93.967       0.2130        0.0657          0.000000         0.687
# 6371  135.021       0.1060        0.2360          0.000000         0.864
# 6372  135.021       0.1060        0.2360          0.000000         0.864
# 6373  165.995       0.3420        0.1450          0.000000         0.808
# 6374  139.956       0.3440        0.0472          0.000000         0.843
#
#      duration_ms  loudness  valence mode key
# 0         170972    -5.313    0.824    1   2
# 1         157967    -7.589    0.634    0  10
# 2         240253    -4.496    0.514    1   1
# 3         157967    -7.589    0.634    0  10
# 4         170972    -5.313    0.824    1   2
# ...          ...       ...      ...  ...  ..
# 6370      224681    -4.247    0.848    0   6
# 6371      194748    -5.489    0.858    1   8
# 6372      194748    -5.489    0.858    1   8
# 6373      210800    -5.260    0.829    0  10
# 6374      217250    -2.893    0.430    0  10
#
# [6375 rows x 18 columns]

# %%
# Delete songs that played for 0ms
my_streaming_data.drop(my_streaming_data[my_streaming_data["ms_played"]==0].index, inplace=True)
my_streaming_data
# Out:
#      artist_name                   track_name          end_time  ms_played  \
# 0      Bad Bunny             Si Veo a Tu Mamá  2020-06-18 21:53     170971
# 1      Bad Bunny                           <3  2020-06-18 21:56     157967
# 2      Bad Bunny              Hablamos Mañana  2020-06-18 22:00     240253
# 3      Bad Bunny                           <3  2020-06-18 22:13       4759
# 4      Bad Bunny             Si Veo a Tu Mamá  2020-06-18 23:55       1040
# ...          ...                          ...               ...        ...
# 6370        Acru                        Crudo  2020-12-16 23:14      92115
# 6371      Trueno                     Atrevido  2020-12-16 23:37       1707
# 6372      Trueno                     Atrevido  2020-12-16 23:40     194747
# 6373      Eminem  Godzilla (feat. Juice WRLD)  2020-12-16 23:44     210800
# 6374        Duki                  Hello Cotto  2020-12-16 23:47     217250
#
#                     track_id                 song_id  energy  liveness  \
# 0     41wtwzCZkXwpnakmwJ239F  41wtwzCZkXwpnakmwJ239F   0.603    0.1340
# 1     4MZSqgwlE71CWZ6qQ3gkKm  4MZSqgwlE71CWZ6qQ3gkKm   0.665    0.1520
# 2     1V8XneTrX6kKeoxYbk4x6h  1V8XneTrX6kKeoxYbk4x6h   0.677    0.0998
# 3     4MZSqgwlE71CWZ6qQ3gkKm  4MZSqgwlE71CWZ6qQ3gkKm   0.665    0.1520
# 4     41wtwzCZkXwpnakmwJ239F  41wtwzCZkXwpnakmwJ239F   0.603    0.1340
# ...                      ...                     ...     ...       ...
# 6370  3Y0njfS1jG0EzUDKtjvS5a  3Y0njfS1jG0EzUDKtjvS5a   0.827    0.2230
# 6371  6tMqYyCVU2aKgUahMvJz2S  6tMqYyCVU2aKgUahMvJz2S   0.640    0.3740
# 6372  6tMqYyCVU2aKgUahMvJz2S  6tMqYyCVU2aKgUahMvJz2S   0.640    0.3740
# 6373  7FIWs0pqAYbP91WWM0vlTQ  7FIWs0pqAYbP91WWM0vlTQ   0.745    0.2920
# 6374  422Avi2VjqZKCVzstKmqog  422Avi2VjqZKCVzstKmqog   0.785    0.0506
#
#         tempo  speechiness  acousticness  instrumentalness  danceability  \
# 0     129.928       0.0646        0.4020          0.000005         0.900
# 1      80.353       0.2290        0.6020          0.000002         0.631
# 2     156.019       0.0469        0.0869          0.000000         0.683
# 3      80.353       0.2290        0.6020          0.000002         0.631
# 4     129.928       0.0646        0.4020          0.000005         0.900
# ...       ...          ...           ...               ...           ...
# 6370   93.967       0.2130        0.0657          0.000000         0.687
# 6371  135.021       0.1060        0.2360          0.000000         0.864
# 6372  135.021       0.1060        0.2360          0.000000         0.864
# 6373  165.995       0.3420        0.1450          0.000000         0.808
# 6374  139.956       0.3440        0.0472          0.000000         0.843
#
#      duration_ms  loudness  valence mode key
# 0         170972    -5.313    0.824    1   2
# 1         157967    -7.589    0.634    0  10
# 2         240253    -4.496    0.514    1   1
# 3         157967    -7.589    0.634    0  10
# 4         170972    -5.313    0.824    1   2
# ...          ...       ...      ...  ...  ..
# 6370      224681    -4.247    0.848    0   6
# 6371      194748    -5.489    0.858    1   8
# 6372      194748    -5.489    0.858    1   8
# 6373      210800    -5.260    0.829    0  10
# 6374      217250    -2.893    0.430    0  10
#
# [6331 rows x 18 columns]

# %%
# Scale feature to between 0 and 1 using normalization
def scale_feature(df, col):
    max_val = df[col].max()
    min_val = df[col].min()
    val_range = max_val - min_val
    df[col+'_adj']=df[col].apply(lambda x: ((x-min_val)/(max_val-min_val)))
    return

scale_feature(my_streaming_data, 'loudness')
my_streaming_data['loudness_adj']
# Out:
# 0       0.859578
# 1       0.805909
# 2       0.878844
# 3       0.805909
# 4       0.859578
#           ...
# 6370    0.884715
# 6371    0.855428
# 6372    0.855428
# 6373    0.860828
# 6374    0.916643
# Name: loudness_adj, Length: 6331, dtype: float64

# %%
my_streaming_data
# Out:
#      artist_name                   track_name          end_time  ms_played  \
# 0      Bad Bunny             Si Veo a Tu Mamá  2020-06-18 21:53     170971
# 1      Bad Bunny                           <3  2020-06-18 21:56     157967
# 2      Bad Bunny              Hablamos Mañana  2020-06-18 22:00     240253
# 3      Bad Bunny                           <3  2020-06-18 22:13       4759
# 4      Bad Bunny             Si Veo a Tu Mamá  2020-06-18 23:55       1040
# ...          ...                          ...               ...        ...
# 6370        Acru                        Crudo  2020-12-16 23:14      92115
# 6371      Trueno                     Atrevido  2020-12-16 23:37       1707
# 6372      Trueno                     Atrevido  2020-12-16 23:40     194747
# 6373      Eminem  Godzilla (feat. Juice WRLD)  2020-12-16 23:44     210800
# 6374        Duki                  Hello Cotto  2020-12-16 23:47     217250
#
#                     track_id                 song_id  energy  liveness  \
# 0     41wtwzCZkXwpnakmwJ239F  41wtwzCZkXwpnakmwJ239F   0.603    0.1340
# 1     4MZSqgwlE71CWZ6qQ3gkKm  4MZSqgwlE71CWZ6qQ3gkKm   0.665    0.1520
# 2     1V8XneTrX6kKeoxYbk4x6h  1V8XneTrX6kKeoxYbk4x6h   0.677    0.0998
# 3     4MZSqgwlE71CWZ6qQ3gkKm  4MZSqgwlE71CWZ6qQ3gkKm   0.665    0.1520
# 4     41wtwzCZkXwpnakmwJ239F  41wtwzCZkXwpnakmwJ239F   0.603    0.1340
# ...                      ...                     ...     ...       ...
# 6370  3Y0njfS1jG0EzUDKtjvS5a  3Y0njfS1jG0EzUDKtjvS5a   0.827    0.2230
# 6371  6tMqYyCVU2aKgUahMvJz2S  6tMqYyCVU2aKgUahMvJz2S   0.640    0.3740
# 6372  6tMqYyCVU2aKgUahMvJz2S  6tMqYyCVU2aKgUahMvJz2S   0.640    0.3740
# 6373  7FIWs0pqAYbP91WWM0vlTQ  7FIWs0pqAYbP91WWM0vlTQ   0.745    0.2920
# 6374  422Avi2VjqZKCVzstKmqog  422Avi2VjqZKCVzstKmqog   0.785    0.0506
#
#         tempo  speechiness  acousticness  instrumentalness  danceability  \
# 0     129.928       0.0646        0.4020          0.000005         0.900
# 1      80.353       0.2290        0.6020          0.000002         0.631
# 2     156.019       0.0469        0.0869          0.000000         0.683
# 3      80.353       0.2290        0.6020          0.000002         0.631
# 4     129.928       0.0646        0.4020          0.000005         0.900
# ...       ...          ...           ...               ...           ...
# 6370   93.967       0.2130        0.0657          0.000000         0.687
# 6371  135.021       0.1060        0.2360          0.000000         0.864
# 6372  135.021       0.1060        0.2360          0.000000         0.864
# 6373  165.995       0.3420        0.1450          0.000000         0.808
# 6374  139.956       0.3440        0.0472          0.000000         0.843
#
#      duration_ms  loudness  valence mode key  loudness_adj
# 0         170972    -5.313    0.824    1   2      0.859578
# 1         157967    -7.589    0.634    0  10      0.805909
# 2         240253    -4.496    0.514    1   1      0.878844
# 3         157967    -7.589    0.634    0  10      0.805909
# 4         170972    -5.313    0.824    1   2      0.859578
# ...          ...       ...      ...  ...  ..           ...
# 6370      224681    -4.247    0.848    0   6      0.884715
# 6371      194748    -5.489    0.858    1   8      0.855428
# 6372      194748    -5.489    0.858    1   8      0.855428
# 6373      210800    -5.260    0.829    0  10      0.860828
# 6374      217250    -2.893    0.430    0  10      0.916643
#
# [6331 rows x 19 columns]

# %%
# FINISHED DATA MANIPULATION STAGE

# %%
# Getting averages for interesting features in songs

def get_feature_average(df, feature):
    return df[feature].mean()

features_of_interest = ["energy", "liveness", "speechiness", "acousticness", "instrumentalness", "danceability", "loudness_adj"]
features_average = list()
for feature in features_of_interest:
    features_average.append(get_feature_average(my_streaming_data, feature=feature))

# %%
# Create radar chart
radar_data = pd.DataFrame(dict(
    r=features_average,
    theta=features_of_interest))
fig = px.line_polar(df, r='r', theta='theta', line_close=True)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-ee694242ddc0> in <module>
#       3     r=features_average,
#       4     theta=features_of_interest))
# ----> 5 fig = px.line_polar(df, r='r', theta='theta', line_close=True)
#       6 fig.show()
#
# NameError: name 'px' is not defined
